# %%
import pandas as pd

# %% [markdown]
# # 1 Read a .csv from a URL with Pandas
#
# tarjet website: "Link de la web deseada"

# %%
Nombre_data_frame = pd.read_csv("Tarjet website")

# %%
# Showing data frame
Nombre_data_frame
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0    E0  05/08/2022  20:00  Crystal Palace         Arsenal     0     2   A
# 1    E0  06/08/2022  12:30          Fulham       Liverpool     2     2   D
# 2    E0  06/08/2022  15:00     Bournemouth     Aston Villa     2     0   H
# 3    E0  06/08/2022  15:00           Leeds          Wolves     2     1   H
# 4    E0  06/08/2022  15:00       Newcastle   Nott'm Forest     2     0   H
# ..   ..         ...    ...             ...             ...   ...   ...  ..
# 131  E0  06/11/2022  12:00         Chelsea         Arsenal     0     1   A
# 132  E0  06/11/2022  14:00     Aston Villa      Man United     3     1   H
# 133  E0  06/11/2022  14:00     Southampton       Newcastle     1     4   A
# 134  E0  06/11/2022  14:00        West Ham  Crystal Palace     1     2   A
# 135  E0  06/11/2022  16:30       Tottenham       Liverpool     1     2   A
#
# ...

# %%
# Rename columns

Nombre_data_frame.rename(columns = {"Clave1" : "Valor1 ",
"Clave2" : "Valor2"}, inplace = True )

# %%
# Show data frame
Nombre_data_frame
# Out:
#     Div        Date   Time        HomeTeam        AwayTeam  Home_goals   \
# 0    E0  05/08/2022  20:00  Crystal Palace         Arsenal            0
# 1    E0  06/08/2022  12:30          Fulham       Liverpool            2
# 2    E0  06/08/2022  15:00     Bournemouth     Aston Villa            2
# 3    E0  06/08/2022  15:00           Leeds          Wolves            2
# 4    E0  06/08/2022  15:00       Newcastle   Nott'm Forest            2
# ..   ..         ...    ...             ...             ...          ...
# 131  E0  06/11/2022  12:00         Chelsea         Arsenal            0
# 132  E0  06/11/2022  14:00     Aston Villa      Man United            3
# 133  E0  06/11/2022  14:00     Southampton       Newcastle            1
# 134  E0  06/11/2022  14:00        West Ham  Crystal Palace            1
# 135  E0  06/11/2022  16:30       Tottenham       Liverpool            1
#
#      Away_goals FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  \
# ...
